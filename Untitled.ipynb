# %%
import pandas as pd

# %%
data = pd.read_pickle("./tags_2_1_june")

# %%
data
# Out:
#                   tags  question_id  \
# 0           javascript     68109858
# 1        accessibility     68109858
# 2   keyboard-shortcuts     68109858
# 3             shortcut     68109858
# 0           javascript     68001450
# ..                 ...          ...
# 2                shiny     20473821
# 0           javascript     20126906
# 1                  php     20126906
# 2              gettext     20126906
# 3              confirm     20126906
#
#                                                 title label
# 0   Is overriding common browser shortcuts like ct...     s
# 1   Is overriding common browser shortcuts like ct...     s
# 2   Is overriding common browser shortcuts like ct...     s
# 3   Is overriding common browser shortcuts like ct...     s
# 0   Overriding Object.entries()&#39;s types causes...     s
# ..                                                ...   ...
# 2   How to add JavaScript to change CSS file in R ...     r
# ...
